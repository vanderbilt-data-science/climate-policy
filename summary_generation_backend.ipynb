# %%
import os
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_community.document_loaders import PyPDFLoader
from langchain_core.vectorstores import InMemoryVectorStore
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Set up OpenAI API key
import getpass
os.environ["OPENAI_API_KEY"] = getpass.getpass()

# %%
# Load the PDF document
file_path = "Resilient_Los_Angeles_Plan.pdf"
loader = PyPDFLoader(file_path)
docs = loader.load()

# Split the document into smaller chunks for embedding
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
splits = text_splitter.split_documents(docs)

# Create vector store and retriever
vectorstore = InMemoryVectorStore.from_documents(
    documents=splits, embedding=OpenAIEmbeddings()
)
retriever = vectorstore.as_retriever()

# Read the system prompt from a Markdown (.md) file
prompt_file_path = "summary_tool_system_prompt.md"
if os.path.exists(prompt_file_path):
    with open(prompt_file_path, "r") as file:
        system_prompt = file.read()
else:
    raise FileNotFoundError(f"The specified file was not found: {prompt_file_path}")

# Ensure the system prompt includes {context} for document input
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        ("human", "{input}"),
    ]
)

# Create the retrieval and question-answering chains
llm = ChatOpenAI(model="gpt-4o")
question_answer_chain = create_stuff_documents_chain(llm, prompt, document_variable_name="context")
rag_chain = create_retrieval_chain(retriever, question_answer_chain)

# Load questions from a Markdown file
questions_file_path = "summary_tool_questions.md"
if os.path.exists(questions_file_path):
    with open(questions_file_path, "r") as file:
        questions = [line.strip() for line in file.readlines() if line.strip()]
else:
    raise FileNotFoundError(f"The specified file was not found: {questions_file_path}")

# Iterate through questions and invoke the RAG chain for each
for question in questions:
    result = rag_chain.invoke({"input": question})
    # Extract only the answer from the result and print it
    answer = result["answer"]
    print(f"Answer: {answer}\n")
# Out:
# Answer: The plan provides information about the city of Los Angeles. Los Angeles is described as having over four million residents, with over one million buildings, and 500,000 active businesses. The city spans nearly 500 square miles, indicating its vast geographical area *(Los Angeles’ Health Atlas and other City resources; Page number not provided)*. However, specific details about major industries or per capita income are not included in the provided excerpts from the plan.
#
# Answer: The plan addresses resilience, mitigation, and adaptation through various initiatives and strategies, as outlined below:
#
# ### **Resilience:**
# - The plan emphasizes incorporating resilience as a guiding principle into government planning documents, specifically the General Plan and Zoning Code. This is to ensure that land-use decisions enhance the ability of individuals, neighborhoods, and economic systems to recover from disasters, climate change, and economic shifts *(Goal 8, Page 44)*.
# - The plan outlines specific resilience actions such as applying resilience criteria to capital planning and critical infrastructure projects by 2022, investing in green infrastructure and stormwater retention by 2028, modernizing the power grid for renewable energy expansion by 2036, and investing in vulnerable buildings to withstand seismic and climate threats by 2043 *(Leadership and Engagement, Page 44)*.
#
# ### **Mitigation:**
# - A mitigation focus is seen in the goal to modernize the power grid to expand renewable energy to 65% of the power source by 2036. This effort aims to reduce greenhouse gas emissions by transitioning to renewable energy sources *(Leadership and Engagement, Page 44)*.
#
# ### **Adaptation:**
# - The plan mentions specific adaptation strategies, such as investing in green infrastructure to capture water for reuse, improve water quality, and reduce flooding risks by 2028. This strategy directly addresses the adaptation to increased rainfall and flood events *(Leadership and Engagement, Page 44)*.
# - The plan also suggests modernizing infrastructure to enhance adaptive capacity, which includes increasing real-time data gathering and sharing tools *(Leadership and Engagement, Page 44)*.
#
# Overall, the plan integrates resilience, mitigation, and adaptation across various sectors such as energy, transportation, land use, and public health, ensuring a comprehensive approach to addressing climate change impacts.
#
# Answer: Yes, the plan describes a scenario of climate change that the planning jurisdiction is addressing through resilience, mitigation, and adaptation policies. It outlines the necessity to proactively address various climate impacts such as flood risk, and the need to develop infrastructure that is reliable in the face of future climate impacts and hazards. The plan emphasizes transitioning to zero-emissions technology and fossil-fuel-free streets to tackle air pollution and climate change. Additionally, it mentions the incorporation of sea level rise modeling into local plans to account for future climate scenarios *(GOAL 12: USE CLIMATE SCIENCE TO DEVELOP ADAPTATION STRATEGIES CONSISTENT WITH THE PARIS CLIMATE AGREEMENT)*.
#
# Answer: The plan identifies several climate impacts and the associated climate risks, along with populations or areas that are most vulnerable:
#
# 1. **Energy, Transportation, and Land Use:**
#    - **Climate Impact:** The plan highlights risks related to energy, transportation, and land use systems.
#    - **Climate Risks:** These systems are vulnerable to disruptions due to climate change, which can affect the ability to maintain essential services and functions.
#    - **Vulnerability:** Populations relying heavily on these systems, particularly in areas where infrastructure may be outdated or insufficient, are most vulnerable. The plan emphasizes the need for resilience in these areas to ensure that systems can recover from climate disruptions *(Chapter name, Section header, Page number etc. if applicable)*.
#
# 2. **Ocean and Coastal Resources:**
#    - **Climate Impact:** Ocean and coastal resources are identified as vulnerable to climate change impacts such as rising sea levels and increased storm intensity.
#    - **Climate Risks:** These impacts can lead to coastal erosion, flooding, and habitat loss, threatening both natural ecosystems and human settlements.
#    - **Vulnerability:** Coastal communities and ecosystems are most at risk, with potential impacts on livelihoods, property, and local economies *(Chapter name, Section header, Page number etc. if applicable)*.
#
# 3. **Water:**
#    - **Climate Impact:** The plan discusses water-related climate impacts, including droughts and changes in precipitation patterns.
#    - **Climate Risks:** These changes pose risks to water supply, quality, and management, potentially leading to shortages and increased competition for water resources.
#    - **Vulnerability:** Areas with limited water infrastructure or those dependent on vulnerable water sources are particularly at risk. Populations with limited access to alternative water supplies may face increased vulnerability *(Chapter name, Section header, Page number etc. if applicable)*.
#
# 4. **Public Health:**
#    - **Climate Impact:** Public health is impacted by climate change through extreme weather events, heatwaves, and the spread of diseases.
#    - **Climate Risks:** These impacts can exacerbate health problems, strain healthcare systems, and lead to increased mortality and morbidity.
#    - **Vulnerability:** Vulnerable populations include the elderly, children, those with preexisting health conditions, and low-income communities who may have less access to healthcare resources *(Chapter name, Section header, Page number etc. if applicable)*.
#
# The plan emphasizes the importance of integrating risk and vulnerability assessments into community planning processes to address these challenges and opportunities effectively *(Chapter name, Section header, Page number etc. if applicable)*.
#
# Answer: The plan "Resilient Los Angeles" identifies several resilience options aimed at building resilience to both catastrophic events and chronic stresses. Below are the resilience options mentioned and their associated details based on the plan:
#
# 1. **Integration of Resilience Principles into Government Planning:**
#     - **Summary:** The City of Los Angeles plans to incorporate resilience as a guiding principle in planning documents that inform land use and development. This includes integrating resilience into long-range planning initiatives already underway, such as updating the citywide General Plan and the Zoning Code. These updates should incorporate climate adaptation, hazard mitigation, and recovery efforts.
#     - **Cost:** The document does not specify the cost associated with this option.
#     - **Timing:** This action is identified as a short-term timeframe, which means it is expected to be implemented in five years or less.
#     - **Location:** The location is citywide as it pertains to the General Plan and Zoning Code updates for Los Angeles.
#     - **Other Attributes:** The plan emphasizes the need for an integrated approach to risk management, which can save money and promote a safe and thriving city *(Resilient Los Angeles, Goal 8: Integrate Resilience Principles into Government)*.
#
# The plan organizes actions by scale and goal, and each action is accompanied by a title, description, associated shocks and stresses, timeframe, and partners. Additional details such as measuring and tracking outcomes over time are highlighted as important components of resilience building *(Resilient Los Angeles, Chapter Overview)*.
#
# For a comprehensive understanding of all resilience options, interested parties should refer to the full document, which lists actions by theme at the end of the report.
#
# Answer: The plan identifies several mitigation options aimed at reducing greenhouse gas emissions and enhancing infrastructure resilience. Below are the key mitigation options along with their attributes:
#
# 1. **Develop a Clean Energy and Smart Grid Infrastructure:**
#    - **Timing:** Not explicitly mentioned.
#    - **Location:** Not explicitly mentioned, but it is implied to be city-wide.
#    - **Attributes:** The plan mentions the development of a reliable clean energy and smart grid infrastructure to address future climate impacts and hazards. This involves expanding solar and energy storage pilots *(Page not specified)*.
#
# 2. **Expand Electric Fleets and Charging Infrastructure:**
#    - **Timing:** Not explicitly mentioned.
#    - **Location:** Not explicitly mentioned, but it is implied to be city-wide.
#    - **Attributes:** This option focuses on reducing emissions by expanding electric vehicle fleets, charging infrastructure, and energy backup systems to support emergency and response services *(Page not specified)*.
#
# 3. **Leverage Airport Modernization:**
#    - **Timing:** Not explicitly mentioned.
#    - **Location:** Los Angeles World Airports.
#    - **Attributes:** The plan includes leveraging the modernization of airports to increase resilience, which may also contribute to emission reductions *(Page not specified)*.
#
# 4. **Implement Stormwater Projects:**
#    - **Timing:** Not explicitly mentioned.
#    - **Location:** Not explicitly mentioned, but implied to be city-wide.
#    - **Attributes:** These projects aim to reduce pollution and capture local water supply, thereby potentially reducing emissions associated with water management *(Page not specified)*.
#
# 5. **Revitalize and Protect the Los Angeles River Watershed:**
#    - **Timing:** Not explicitly mentioned.
#    - **Location:** Los Angeles River Watershed.
#    - **Attributes:** This involves enhancing and protecting the ecosystem and biodiversity of the watershed, which can contribute to carbon sequestration and emission reductions *(Page not specified)*.
#
# The plan does not provide specific cost details or exact timing for these mitigation options. However, it emphasizes the collaborative efforts with various partners to achieve these goals and enhance the city's resilience *(Page not specified)*.
#
# Answer: Based on the excerpt provided from the plan, here are the identified adaptation options:
#
# 1. **Incorporate Sea Level Rise Modeling into Local Plans**
#    - **Climate Threat Addressed:** This option addresses the threat of rising sea levels, which can lead to coastal flooding and erosion, impacting coastal communities and infrastructure.
#    - **Attributes:** The plan mentions the action of incorporating sea level rise modeling, but it does not provide specific details on cost, timing, or location within the provided excerpt. It emphasizes the importance of integrating scientific modeling into planning to mitigate potential impacts *(Chapter 4, Goal 12)*.
#
# 2. **Ensure Climate Resilience and Adaptation Planning is Robust and Consistent with the Paris Climate Agreement**
#    - **Climate Threat Addressed:** This option is addressing the broader threat of climate change, which includes extreme weather events, temperature changes, and their associated impacts on infrastructure and communities.
#    - **Attributes:** The plan underscores the importance of aligning adaptation strategies with international standards, specifically the Paris Climate Agreement. However, specific information regarding cost, timing, and location is not detailed in the provided section *(Chapter 4, Goal 12)*.
#
# These adaptation options highlight the planning jurisdiction's focus on integrating scientific research and global frameworks into local planning efforts to enhance resilience against climate change threats. The provided excerpt does not include detailed information on costs, specific timelines, or precise locations for these initiatives.
#
# Answer: Based strictly on the content provided in the document, the plan identifies the following climate policies to advance climate justice:
#
# 1. **Develop resilience hubs in our most vulnerable neighborhoods by 2028.**
#    - **Climate Threat:** This policy is addressing the threat of increased climate impacts that can affect vulnerable neighborhoods disproportionately.
#    - **Areas/Populations with Climate Vulnerability:** The most vulnerable neighborhoods are identified as areas with the greatest need for resilience hubs, indicating a focus on populations that are at higher risk due to socioeconomic factors and potentially greater exposure to climate impacts.
#
# 2. **Develop and implement urban heat island reduction plans and demonstration projects in our most vulnerable neighborhoods by 2022.**
#    - **Climate Threat:** The threat being addressed here is the urban heat island effect, which can lead to higher temperatures in urban areas, exacerbating heat-related health issues.
#    - **Areas/Populations with Climate Vulnerability:** The policy targets the most vulnerable neighborhoods, which are likely to be those with less green space, poorer housing conditions, and lower socioeconomic status, making them more susceptible to heat-related stresses.
#
# 3. **Increase equitable tree canopy coverage by 2028.**
#    - **Climate Threat:** This policy addresses the threat of heat and air pollution, as increased tree canopy can help mitigate high temperatures and improve air quality.
#    - **Areas/Populations with Climate Vulnerability:** The focus on equitable coverage suggests a prioritization of neighborhoods that currently have less tree cover and therefore more exposure to heat and air quality issues, often correlating with underserved or marginalized communities.
#
# 4. **Increase access to green space and open space through investments along the Los Angeles River system and in underserved neighborhoods by 2028.**
#    - **Climate Threat:** This policy aims to address the lack of access to green and open spaces, which can exacerbate the impacts of climate change by limiting areas for cooling and recreation.
#    - **Areas/Populations with Climate Vulnerability:** The policy specifically targets underserved neighborhoods, recognizing these populations as having less access to green spaces that can mitigate climate impacts and improve quality of life.
#
# *(Chapter 4, Goals and Actions)*
#
# Answer: Based strictly on the provided text from the plan, there is no explicit mention of climate policies that could be considered potential maladaptation. The plan outlines various climate policies that aim to enhance resilience, mitigate emissions, and adapt to climate impacts, as detailed below:
#
# 1. **Develop an Urban Heat Vulnerability Index and Mitigation Plan**
#    - **Climate Threat Addressed:** Higher temperatures and more frequent extreme heat.
#    - **Option Proposed:** This is an adaptation option, aiming to prepare for and mitigate the impacts of increasing temperatures through the development of a vulnerability index and mitigation plan *(Appendix B: Summary of Actions by Interest Area, Page 166)*.
#
# 2. **Develop and Launch a Neighborhood Retrofit Pilot Program**
#    - **Climate Threat Addressed:** Higher temperatures.
#    - **Option Proposed:** This is an adaptation option, testing cooling strategies to better prepare neighborhoods for higher temperatures *(Appendix B: Summary of Actions by Interest Area, Page 166)*.
#
# 3. **Expand and Protect Water Sources**
#    - **Climate Threat Addressed:** Dependence on imported water, potentially exacerbated by climate variability and water scarcity.
#    - **Option Proposed:** This is an adaptation option, aiming to reduce reliance on external water sources and strengthen local water supply, enhancing resilience to water scarcity *(Appendix B: Summary of Actions by Interest Area, Page 166)*.
#
# Without specific indications of maladaptation, these policies appear focused on strengthening resilience, adaptation, and mitigation efforts in response to climate threats.
#
# Answer: The plan outlines several strategies for monitoring and evaluating the progress of implementing resilience options. It emphasizes the importance of measuring and tracking outcomes over time to ensure success in achieving resilience goals. Specifically, the plan mentions that the City will "track and report on resilience outcomes that show measurable progress for our most vulnerable populations and neighborhoods by 2022" *(Leadership and Engagement)*. This suggests a focus on accountability and transparency in assessing the effectiveness of resilience strategies, particularly for the most vulnerable groups. Additionally, the plan aims to "increase real-time data gathering and sharing tools to improve adaptive capacity," which highlights an effort to utilize technology for ongoing evaluation and adaptation of policies.
#
# Answer: Based on the content provided, here is a table summarizing the requested features from the document:
#
# | **Feature**            | **Details**                                                                                                                                                       |
# |------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **Location/City Name** | Los Angeles                                                                                                                                                       |
# | **Population**         | Not explicitly mentioned in the provided content.                                                                                                                 |
# | **Threats Identified** | - Inequity<br>- Education<br>- Homelessness<br>- Lack of Affordable Housing<br>- Crime and Violence<br>- Disparities in Employment<br>- Disparities in Health<br>- Disparities in Access to Open Space<br>- Disparities in Access to Transit<br>- Food Insecurity<br>- Climate Change<br>- Air Quality/Pollution<br>- Urban Heat Island<br>- Extreme Heat<br>- Drought<br>- Severe Weather and Flooding<br>- Sea Level Rise<br>- Extreme Cold<br>- Aging Infrastructure<br>- Infrastructure or Building Failure |
# | **Measures Identified**| - Development of equity indicators to support disadvantaged groups *(Chapter name, Section header, Page number etc. if applicable)*<br>- Incorporation of climate adaptation in land-use decisions *(Chapter name, Section header, Page number etc. if applicable)*<br>- Incorporating green infrastructure and open space *(Chapter name, Section header, Page number etc. if applicable)*<br>- Training City staff and partners to use the Climate-Smart Cities tool *(Chapter name, Section header, Page number etc. if applicable)* |
#
# Please note that the specific chapter names, section headers, and page numbers are not available in the provided content.
